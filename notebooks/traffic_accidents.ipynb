# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
zipcodes = gpd.read_file('../data/zipcodes.geojson')
print(zipcodes.crs)
zipcodes.head( )
# Out:
# epsg:4326
#      zip objectid    po_name      shape_stlength        shape_starea  \
# 0  37115        1    MADISON  178783.02488886821  596553400.57885742
# 1  37216        3  NASHVILLE  75820.997821400058  188884682.28344727
# 2  37204        9  NASHVILLE  93180.292250425613  200664795.51708984
# 3  37027       11  BRENTWOOD   159760.6942933173  174978422.04101562
# 4  37064       18   FRANKLIN  28995.828320601937  46969608.005737305
#
#                                             geometry
# 0  MULTIPOLYGON (((-86.68725 36.31821, -86.68722 ...
# 1  MULTIPOLYGON (((-86.73451 36.23774, -86.73425 ...
# 2  MULTIPOLYGON (((-86.77914 36.13424, -86.77923 ...
# 3  MULTIPOLYGON (((-86.81258 36.06319, -86.81263 ...
# 4  MULTIPOLYGON (((-87.02197 36.01200, -87.02140 ...

# %%
traffic_accidents = gpd.read_file('../data/Traffic Accidents.geojson')
print(traffic_accidents.crs)
traffic_accidents.head( )
# Out:
# epsg:4326
#         city   rpa    zip state weather_description  \
# 0  NASHVILLE  1425  37216    TN               CLEAR
# 1  NASHVILLE  9103  37214    TN               CLEAR
# 2  NASHVILLE  8955  37214    TN               CLEAR
# 3  NASHVILLE  1995  37206    TN               CLEAR
# 4    MADISON  1721  37115    TN               CLEAR
#
#           harmfuldescriptions number_of_injuries collision_type  \
# 0  MOTOR VEHICLE IN TRANSPORT                  0              4
# 1  MOTOR VEHICLE IN TRANSPORT                  1              4
# 2  MOTOR VEHICLE IN TRANSPORT                  0              4
# 3  MOTOR VEHICLE IN TRANSPORT                  0              4
# 4                    BUILDING                  0              0
#
#          date_and_time harmfulcodes  ... illuaccidemination accident_number  \
# 0  2022-04-14T17:36:00           12  ...                  1     20220180471
# 1  2022-04-14T18:00:00           12  ...                  1     20220180439
# ...

# %%
type(zipcodes)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
traffic_accidents.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 214914 entries, 0 to 214913
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   city                        214914 non-null  object
#  1   rpa                         213812 non-null  object
#  2   zip                         213819 non-null  object
#  3   state                       214914 non-null  object
#  4   weather_description         209609 non-null  object
#  5   harmfuldescriptions         212668 non-null  object
#  6   number_of_injuries          214914 non-null  object
#  7   collision_type              214898 non-null  object
#  8   date_and_time               214914 non-null  object
#  9   harmfulcodes                214914 non-null  object
#  10  reporting_officer           214904 non-null  object
#  11  hit_and_run                 214897 non-null  object
# ...

# %%
zipcodes.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
traffic_accidents.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
accidents_by_zip = gpd.sjoin(traffic_accidents, zipcodes, op = 'within')

# %%
accidents_by_zip.head()
# Out:
#           city    rpa zip_left state weather_description  \
# 0    NASHVILLE   1425    37216    TN               CLEAR
# 38   NASHVILLE   1837    37216    TN                RAIN
# 65   NASHVILLE  15960    37216    TN               CLEAR
# 197    MADISON   1594    37115    TN              CLOUDY
# 252  NASHVILLE   1439    37216    TN               CLEAR
#
#             harmfuldescriptions number_of_injuries collision_type  \
# 0    MOTOR VEHICLE IN TRANSPORT                  0              4
# 38                 UTILITY POLE                  1              0
# 65   MOTOR VEHICLE IN TRANSPORT                  1             11
# 197  MOTOR VEHICLE IN TRANSPORT                  0             11
# 252  MOTOR VEHICLE IN TRANSPORT                  0              4
#
#            date_and_time harmfulcodes  ... illumination_description  \
# 0    2022-04-14T17:36:00           12  ...                 DAYLIGHT
# 38   2022-04-13T00:00:00           30  ...           DARK - LIGHTED
# ...

# %%
accidents_by_zip['zip'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\geospatial\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\.conda\envs\geospatial\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\.conda\envs\geospatial\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'zip'
#
# The above exception was the direct cause of the following exception:
#
# ...
